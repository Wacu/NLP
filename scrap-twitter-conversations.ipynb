# %%
# Imports
# !pip install tweepy

import tweepy
import pandas as pd
import time

from tweepy import API 
from tweepy import Cursor
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from textblob import TextBlob

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re

# %%
consumer_key = "XXXXXXXXXXXXXXXXXXXXXXXs"
consumer_secret = "eXNjPXXXXXXXXXXXXXXXXXXXXXXXqmnSlHe97"
access_token = "377520XXXXXXXXXXXXXXXXXXXXXXXXXXXXXcme3yfN"
access_token_secret = "PgXXXXXXXXXXXXXXXXXXXXXXXXXXXXXfP7fKMN"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
tweets = []

def text_query_to_csv(text_query,count):
    try:
    # Pulling individual tweets from query
        for tweet in api.search(q=text_query, count=count):

          # Adding to list that contains all tweets
          tweets.append((tweet.created_at,tweet.id,tweet.text,tweet.source,tweet.favorite_count,tweet.retweet_count))

          # Creation of dataframe from tweets list
          tweetsdf = pd.DataFrame(tweets,columns=['Datetime', 'Tweet Id', 'Text', 'Source', 'Favourite Count', 'Retweets'])

          # Converting dataframe to CSV
          tweetsdf.to_csv('{}-tweets.csv'.format(text_query)) 

    except BaseException as e:
        print('failed on_status,',str(e))
        time.sleep(3)

# %%
# Input search query to scrape tweets and name csv file
# Max recent tweets pulls x amount of most recent tweets from that user
text_query = 'IkoKaziKe'
count = 30000

# Calling function to query X amount of relevant tweets and create a CSV file
text_query_to_csv(text_query, count)

# %% [markdown]
# ## Using twint

# %%
if __name__ == '__main__':

    twitter_client = TwitterClient()
    tweet_analyzer = TweetAnalyzer()

    api = twitter_client.get_twitter_client_api()

    tweets = api.user_timeline(screen_name="IkoKaziKe", count=1000)

    #print(dir(tweets[0]))
    #print(tweets[0].retweet_count)

    tweets_df = tweet_analyzer.tweets_to_data_frame(tweets)

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 7 columns):
# tweets      199 non-null object
# id          199 non-null int64
# len         199 non-null int32
# date        199 non-null datetime64[ns]
# source      199 non-null object
# likes       199 non-null int32
# retweets    199 non-null int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 8.6+ KB

# %%
tweets_df.sample(10)
# Out:
#                                                 tweets                   id  \
# 162  RT @framk69: Exquisite hand stitched leather s...  1282983467484016640
# 122  RT @CampoeKE: Entry-Level Jobs at The Nairobi ...  1283026742433574913
# 166  RT @EvansIsaya: A friend of a friend is lookin...  1282953892209102849
# 84   RT @KaziQuest: Looking for more job opportunit...  1283160567604080641
# 34   RT @Simon_Ingari: Join Job Links WhatsApp Grou...  1283314036788977665
# 185  RT @KaziQuest: Looking for more job opportunit...  1282797530753806338
# 27   Are you a qualified sales agents? @Simon_Ingar...  1283322896555728896
# 22   RT @Antione_Vice: I'm looking for such trucks ...  1283328534618890241
# 149  Are you a qualified it? @FindjobsKenya just po...  1283003377845075969
# 154  RT @Simon_Ingari: Asumbi Mission Hospital Hiri...  1282999523241947136
#
#      len                date          source  likes  retweets
# 162  140 2020-07-14 10:21:09  Iko Kazi Kenya      0         2
# ...
